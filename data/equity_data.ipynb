# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv
from pathlib import Path
import alpaca_trade_api as tradeapi

# %%
load_dotenv()
# Out:
# True

# %%
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

display(type(alpaca_api_key))
display(type(alpaca_secret_key))
# Out:
# str
# str

# %%
alpaca = tradeapi.REST(
     alpaca_api_key,
    alpaca_secret_key,
    api_version="v2")

# %%
nasdaq_df = pd.read_csv(
    Path('rawdata/nasdaq_screener.csv')
)

# %%
nasdaq_df = nasdaq_df.sort_values(by=['Market Cap'], ascending=False)
nasdaq_df = nasdaq_df.reset_index(drop=True)

# %%
nasdaq_filtered_100 = nasdaq_df.iloc[:100]
nasdaq_filtered_200 = nasdaq_df.iloc[100:200]
nasdaq_filtered_300 = nasdaq_df.iloc[200:300]
nasdaq_filtered_400 = nasdaq_df.iloc[300:400]
nasdaq_filtered_500 = nasdaq_df.iloc[400:500]

# %%
tickers_100 = nasdaq_filtered_100['Symbol']
tickers_200 = nasdaq_filtered_200['Symbol']
tickers_300 = nasdaq_filtered_300['Symbol']
tickers_400 = nasdaq_filtered_400['Symbol']
tickers_500 = nasdaq_filtered_500['Symbol']

# %%
start_date = pd.Timestamp("2020-10-31", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2021-11-30", tz="America/New_York").isoformat()
timeframe = "1D"
limit_rows = 1000

# %%
prices_df_100 = alpaca.get_barset(
    tickers_100,
    timeframe,
    start=start_date,
    end=end_date,
    limit=limit_rows
).df

prices_df_100
# Out:
#                              AAPL                                         \
#                              open     high       low    close     volume
# time
# 2020-11-02 00:00:00-05:00  109.11  110.680  107.3200  108.770  106260834
# 2020-11-03 00:00:00-05:00  109.66  111.470  108.7300  110.375   93660131
# 2020-11-04 00:00:00-05:00  114.14  115.590  112.3500  114.940  114505478
# 2020-11-05 00:00:00-05:00  117.99  119.620  116.8686  118.990  107993032
# 2020-11-06 00:00:00-05:00  118.32  119.200  116.1300  118.685   99225280
# ...                           ...      ...       ...      ...        ...
# 2021-11-03 00:00:00-04:00  150.37  151.970  149.8200  151.490   44064848
# 2021-11-04 00:00:00-04:00  151.62  152.430  150.6400  150.960   49782226
# 2021-11-05 00:00:00-04:00  151.81  152.200  150.0600  151.240   54619968
# 2021-11-08 00:00:00-05:00  151.40  151.570  150.1600  150.450   45449352
# 2021-11-09 00:00:00-05:00  150.19  151.428  150.0601  150.710   33656271
#
#                               ABBV                                        ...  \
#                               open      high       low   close    volume  ...
# time                                                                      ...
# 2020-11-02 00:00:00-05:00   86.030   88.5401   86.0000   88.25  17403418  ...
# 2020-11-03 00:00:00-05:00   89.140   89.3850   87.4300   87.97  14519532  ...
# 2020-11-04 00:00:00-05:00   93.135   97.4900   92.6703   94.50  45357361  ...
# 2020-11-05 00:00:00-05:00   95.360   95.5200   93.0000   93.66  13357772  ...
# 2020-11-06 00:00:00-05:00   92.975   93.6500   91.7101   92.86  11544292  ...
prices_df_400 = alpaca.get_barset(
    tickers_400,
    timeframe,
    start=start_date,
    end=end_date,
    limit=limit_rows
).df

# %%
prices_df_500 = alpaca.get_barset(
    tickers_500,
    timeframe,
    start=start_date,
    end=end_date,
    limit=limit_rows
).df

# %%
equity_prices = pd.concat([prices_df_100, prices_df_200, prices_df_300, prices_df_400, prices_df_500])
equity_prices.head()
# Out:
#                               A                          AAPL          \
#                           close high low open volume    close    high
# time
# 2020-11-02 00:00:00-05:00   NaN  NaN NaN  NaN    NaN  108.770  110.68
# 2020-11-03 00:00:00-05:00   NaN  NaN NaN  NaN    NaN  110.375  111.47
# 2020-11-04 00:00:00-05:00   NaN  NaN NaN  NaN    NaN  114.940  115.59
# 2020-11-05 00:00:00-05:00   NaN  NaN NaN  NaN    NaN  118.990  119.62
# 2020-11-06 00:00:00-05:00   NaN  NaN NaN  NaN    NaN  118.685  119.20
#
#                                                           ...    ZS           \
#                                 low    open       volume  ... close high low
# time                                                      ...
# 2020-11-02 00:00:00-05:00  107.3200  109.11  106260834.0  ...   NaN  NaN NaN
# 2020-11-03 00:00:00-05:00  108.7300  109.66   93660131.0  ...   NaN  NaN NaN
# 2020-11-04 00:00:00-05:00  112.3500  114.14  114505478.0  ...   NaN  NaN NaN
# 2020-11-05 00:00:00-05:00  116.8686  117.99  107993032.0  ...   NaN  NaN NaN
# 2020-11-06 00:00:00-05:00  116.1300  118.32   99225280.0  ...   NaN  NaN NaN
#
#                                         ZTS
#                           open volume close high low open volume
# time
# 2020-11-02 00:00:00-05:00  NaN    NaN   NaN  NaN NaN  NaN    NaN
# 2020-11-03 00:00:00-05:00  NaN    NaN   NaN  NaN NaN  NaN    NaN
# 2020-11-04 00:00:00-05:00  NaN    NaN   NaN  NaN NaN  NaN    NaN
# 2020-11-05 00:00:00-05:00  NaN    NaN   NaN  NaN NaN  NaN    NaN
# 2020-11-06 00:00:00-05:00  NaN    NaN   NaN  NaN NaN  NaN    NaN
#
# [5 rows x 2500 columns]

# %%
closing_prices_df = pd.DataFrame()

# %%
for ticker in tickers_100:
    closing_prices_df[ticker] = prices_df_100[ticker]['close']

# %%
for ticker in tickers_200:
    closing_prices_df[ticker] = prices_df_200[ticker]['close']

# %%
for ticker in tickers_300:
    closing_prices_df[ticker] = prices_df_300[ticker]['close']

# %%
for ticker in tickers_400:
    closing_prices_df[ticker] = prices_df_400[ticker]['close']

# %%
for ticker in tickers_500:
    closing_prices_df[ticker] = prices_df_500[ticker]['close']

# %%
closing_prices_df.isnull().sum()
# Out:
# AAPL     0
# MSFT     0
# GOOG     0
# GOOGL    0
# AMZN     0
#         ..
# TEF      0
# ET       0
# GWW      0
# VIACA    0
# EIX      0
# Length: 500, dtype: int64

# %%
closing_prices_df_csv_data = closing_prices_df.to_csv('rawdata/equity_prices.csv')
